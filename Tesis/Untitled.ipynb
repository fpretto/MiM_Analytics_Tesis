# %%
# import dash
# import dash_core_components as dcc
# import dash_html_components as html
# import dash_bootstrap_components as dbc
# from dash.dependencies import Input, Output
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import numpy as np
# import dash_table
import json
import joblib
import sys
PATH_PI = 'C:/Repo/MiM_Analytics_Tesis/Tesis/dash_app/'
sys.path.insert(0, PATH_PI)
from ClassAppPreprocessing import ClassPreprocessing
# Out:
# C:\Users\fabri\AppData\Roaming\Python\Python38\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.0, the latest is 0.5.1.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
# Load data
config_data = json.load(open(PATH_PI+'config_dash.json'))
preprocessing = ClassPreprocessing(config_data)
df_season_players = preprocessing.load_score_process_data(dataset='player_seasons', source='csv', generate_dropdown=False)
df_players = preprocessing.load_score_process_data(dataset='player_all_seasons', source='csv')
dropdown_options = joblib.load(PATH_PI+'data/dropdown_options.pkl')
countries_latam = ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Mexico', 'Peru']
dropdown_options = {country: dropdown_options[country] for country in countries_latam}
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator RobustScaler from version 1.0.1 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator MinMaxScaler from version 1.0.1 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator RobustScaler from version 1.0.1 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator MinMaxScaler from version 1.0.1 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
dict_perf_index = joblib.load('C:/Repo/MiM_Analytics_Tesis/Tesis/performance_index/'+"20220210_PerformanceIndexObject.pkl")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator RobustScaler from version 1.0.1 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator MinMaxScaler from version 1.0.1 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
dict_perf_index
# Out:
# {'cols': {'player_cols': ['league_season',
#    'team_id',
#    'team_name',
#    'player_id',
#    'player_name',
#    'player_preferred_position',
#    'player_minutes',
#    'wavg_player_rating'],
#   'F': ['np_goals_p90',
#    'shots_p90',
#    'shooting_accuracy',
#    'goal_conversion_np',
#    'passing_accuracy',
#    'assists_p90',
#    'key_passes_p90',
#    'dribbles_p90',
#    'dribbles_success_ratio',
#    'tackles_p90',
#    'interceptions_p90'],
#   'M': ['passes_p90',
#    'passing_accuracy',
#    'key_passes_p90',
#    'scoring_contribution',
#    'dribbles_p90',
#    'dribbles_success_ratio',
#    'fouls_drawn_p90',
#    'fouls_committed_p90',
#    'dribbles_past_p90',
#    'tackles_p90',
#    'interceptions_p90'],
#   'D': ['passes_p90',
#    'passing_accuracy',
#    'fouls_drawn_p90',
#    'fouls_committed_p90',
#    'dribbles_past_p90',
#    'duels_p90',
#    'duels_success_ratio',
#    'tackles_p90',
#    'blocks_p90',
#    'interceptions_p90',
#    'penalty_committed_p90'],
#   'G': ['saves_p90',
#    'goals_conceded_p90',
#    'goals_conceded_ratio',
#    'passes_p90',
#    'passing_accuracy',
#    'fouls_drawn_p90',
#    'fouls_committed_p90',
#    'duels_p90',
#    'duels_success_ratio',
#    'tackles_p90',
#    'blocks_p90',
#    'interceptions_p90',
#    'penalty_committed_p90']},
#  'scalers': {'F': RobustScaler(),
#   'M': RobustScaler(),
#   'D': RobustScaler(),
#   'G': RobustScaler()},
#  'index_weights': {'F': {'Factor 1': array([3.53831984e-01, 2.26931420e-02, 2.18388851e-01, 3.68371609e-01,
#           2.44819911e-02, 1.04881651e-03, 6.30099142e-08, 1.23317449e-03,
#           2.55808360e-04, 1.83403083e-03, 7.86052916e-03]),
#    'Factor 2': array([8.07760287e-02, 3.55818930e-01, 7.84426303e-02, 1.49725322e-03,
#           3.64776358e-01, 2.17726569e-07, 7.22519737e-03, 5.09300570e-03,
#           3.24972633e-05, 1.06335572e-01, 2.31011267e-06]),
#    'Factor 3': array([5.17744327e-04, 5.71013378e-03, 2.81907268e-03, 3.05792675e-04,
#           5.34115255e-04, 5.12956458e-01, 4.16729069e-01, 5.64090142e-02,
#           2.79885548e-03, 3.13286388e-04, 9.06458117e-04]),
#    'Factor 4': array([3.68213826e-03, 4.52922854e-03, 2.17514586e-03, 1.54443264e-03,
#           3.39591322e-04, 7.15336514e-06, 4.07526430e-02, 3.01138404e-01,
#           1.51021924e-03, 2.38962148e-01, 4.05358896e-01]),
#    'Factor 5': array([2.42143539e-04, 8.91642587e-03, 1.83530807e-04, 1.80000096e-03,
#           2.88308176e-03, 6.88104463e-04, 1.23452716e-02, 2.60257046e-02,
#           9.04032423e-01, 2.17751405e-02, 2.11081725e-02]),
#    'Weights': array([0.11702962, 0.08444864, 0.07872235, 0.10415518, 0.08427855,
#           0.09881131, 0.09074249, 0.0722367 , 0.11749995, 0.07073644,
#           0.08133876]),
#    'scalers': {'index_scaler': MinMaxScaler(),
#     'Factor 1_scaler': MinMaxScaler(),
#     'Factor 2_scaler': MinMaxScaler(),
#     'Factor 3_scaler': MinMaxScaler(),
#     'Factor 4_scaler': MinMaxScaler(),
#     'Factor 5_scaler': MinMaxScaler()}},
#   'M': {'Factor 1': array([4.33236858e-04, 8.90593861e-06, 3.56611828e-01, 3.02579596e-01,
#           1.40721028e-01, 5.09774315e-03, 1.26135037e-02, 5.77568018e-02,
#           4.07810131e-03, 5.04408266e-03, 1.15055172e-01]),
#    'Factor 2': array([1.50690695e-01, 1.23240657e-02, 1.67835852e-05, 2.74022998e-04,
#           7.71088879e-03, 9.79477451e-05, 1.26063588e-03, 2.04218531e-01,
#           3.92763840e-01, 1.00675325e-01, 1.29967263e-01]),
#    'Factor 3': array([1.74399612e-02, 5.62211899e-01, 5.91602828e-03, 1.78710586e-03,
#           3.96853637e-03, 5.23611337e-04, 1.16730358e-03, 1.91750315e-03,
#           6.09075686e-03, 3.86685418e-01, 1.22918766e-02]),
#    'Factor 4': array([6.06861434e-02, 4.58034520e-05, 2.02962301e-03, 3.59932054e-03,
#           2.10054312e-01, 2.08063304e-03, 5.14555083e-01, 1.57472287e-01,
#           2.51322247e-03, 3.13552194e-04, 4.66500197e-02]),
#    'Factor 5': array([2.57328843e-01, 2.29592670e-04, 5.61004352e-03, 1.28158730e-02,
#           6.24430473e-03, 6.80161235e-01, 5.47267624e-05, 3.39013579e-03,
#           4.36061559e-03, 3.30191499e-03, 2.65027144e-02]),
#    'Weights': array([0.08812525, 0.10263596, 0.09824198, 0.08448461, 0.07828163,
#           0.11295146, 0.09466768, 0.08780757, 0.0871779 , 0.0921921 ,
#           0.07343386]),
#    'scalers': {'index_scaler': MinMaxScaler(),
#     'Factor 1_scaler': MinMaxScaler(),
#     'Factor 2_scaler': MinMaxScaler(),
#     'Factor 3_scaler': MinMaxScaler(),
#     'Factor 4_scaler': MinMaxScaler(),
#     'Factor 5_scaler': MinMaxScaler()}},
#   'D': {'Factor 1': array([0.05119817, 0.00281233, 0.28331409, 0.18628539, 0.17182828,
#           0.12587708, 0.00040735, 0.01539077, 0.16091006, 0.00117196,
#           0.00080452]),
#    'Factor 2': array([2.29115226e-01, 2.28933867e-01, 4.23489402e-04, 1.01053080e-02,
#           5.67508998e-02, 2.83381406e-02, 5.77558309e-04, 3.82362037e-01,
#           5.78689547e-02, 5.43080305e-03, 9.37156466e-05]),
#    'Factor 3': array([2.18255128e-02, 9.17985436e-02, 5.23807441e-03, 1.30300677e-02,
#           6.41431768e-02, 2.23210922e-01, 4.77742154e-01, 3.19340384e-02,
#           5.38879102e-02, 1.69504206e-02, 2.39180344e-04]),
#    'Factor 4': array([7.81356146e-02, 1.15248169e-01, 3.49470120e-03, 1.16821927e-01,
#           5.67399912e-02, 1.20059944e-01, 6.97838840e-03, 1.00799228e-02,
#           5.48292825e-03, 4.86952938e-01, 5.47650160e-06]),
#    'Factor 5': array([1.57730971e-04, 7.90243215e-04, 5.93621231e-03, 7.96111364e-02,
#           6.31336326e-02, 7.19743764e-04, 1.70656825e-04, 6.93798597e-05,
#           7.54433313e-02, 3.29873082e-05, 7.73934945e-01]),
#    'Weights': array([0.08265745, 0.09237656, 0.07065753, 0.08175095, 0.08686122,
#           0.10491624, 0.10267585, 0.09923828, 0.07521861, 0.08977792,
#           0.11386938]),
#    'scalers': {'index_scaler': MinMaxScaler(),
#     'Factor 1_scaler': MinMaxScaler(),
#     'Factor 2_scaler': MinMaxScaler(),
#     'Factor 3_scaler': MinMaxScaler(),
#     'Factor 4_scaler': MinMaxScaler(),
#     'Factor 5_scaler': MinMaxScaler()}},
#   'G': {'Factor 1': array([2.25834930e-04, 3.41908182e-04, 6.85284177e-04, 1.43820162e-04,
#           2.54120730e-03, 5.51953369e-03, 3.09721970e-01, 2.05846115e-01,
#           9.54696957e-03, 1.73041998e-01, 1.24720081e-01, 1.57453230e-01,
#           1.02120477e-02]),
#    'Factor 2': array([0.00144908, 0.01037406, 0.05635535, 0.32671737, 0.37360925,
#           0.00181912, 0.00815829, 0.00370921, 0.00056563, 0.01452781,
#           0.0009322 , 0.01512677, 0.18665586]),
#    'Factor 3': array([1.16844907e-05, 3.69317562e-03, 3.75580559e-04, 1.31935735e-03,
#           1.57928464e-03, 3.28764514e-01, 1.12026882e-03, 2.31200396e-01,
#           4.06023026e-01, 2.93332246e-04, 2.20153318e-02, 3.56362030e-03,
#           4.04291811e-05]),
#    'Factor 4': array([1.15160985e-04, 5.21571309e-01, 4.10834088e-01, 7.87456045e-05,
#           1.72459060e-02, 4.08961048e-05, 1.58286344e-02, 4.42609048e-03,
#           5.94180791e-03, 1.74883047e-04, 1.87089256e-02, 3.21123674e-04,
#           4.71242930e-03]),
#    'Factor 5': array([7.85484145e-01, 4.30082483e-02, 1.11069826e-01, 3.03885293e-02,
#           6.79923229e-03, 1.16313909e-03, 2.51978938e-03, 2.36223030e-04,
#           1.66738708e-03, 2.28920922e-03, 4.47377572e-03, 4.16439563e-04,
#           1.04840559e-02]),
#    'Weights': array([0.11266181, 0.10536501, 0.10469583, 0.07947272, 0.09066903,
#           0.06338203, 0.08501183, 0.0978002 , 0.0797119 , 0.04824695,
#           0.04048569, 0.0447446 , 0.0477524 ]),
#    'scalers': {'index_scaler': MinMaxScaler(),
#     'Factor 1_scaler': MinMaxScaler(),
#     'Factor 2_scaler': MinMaxScaler(),
#     'Factor 3_scaler': MinMaxScaler(),
#     'Factor 4_scaler': MinMaxScaler(),
#     'Factor 5_scaler': MinMaxScaler()}}}}

# %%
dropdown_options
# Out:
# {'Argentina': {'2016/17': {'Racing Club': array(['Lautaro Martinez', 'Lisandro Lopez', 'Pablo Maximiliano Cuadra',
#           'Santiago Rosales', 'Gustavo Bou', 'Marcos Acuna',
#           'Ezequiel Videla', 'Marcelo Meli', 'Luciano Aued',
#           'Diego Gonzalez', 'Ivan Pillud', 'Gaston Diaz', 'Pablo Alvarez',
#           'Marco Torsiglieri', 'Leandro Grimi', 'Miguel Barbieri',
#           'Sergio Vittor', 'Emanuel Insua', 'Gaston Gomez', 'Agustin Orion'],
#          dtype=object),
#    'Velez Sarsfield': array(['Maximiliano Romero', 'Juan Manuel Martinez', 'Mariano Pavone',
#           'Nicolas Delgadillo', 'Santiago Caseres', 'Fabricio Alvarenga',
#           'Nicolas Dominguez', 'Matias Vargas', 'Diego Zabala',
#           'Leandro Desabato', 'Jorge Correa', 'Hector Canteros',
#           'Gonzalo Diaz', 'Maximiliano Caire', 'Brian Cufre',
#           'Lautaro Gianetti', 'Fabian Cubero', 'Emiliano Amor',
#           'Fausto Grillo', 'Cristian Nasuti', 'Fabian Assmann',
#           'Alan Aguerre'], dtype=object),
#    'River Plate': array(['Lucas Alario', 'Sebastian Driussi', 'Rodrigo Mora',
#           'Ignacio Fernandez', 'Leonardo Ponzio', 'Ariel Rojas',
#           'Gonzalo Martinez', 'Joaquin Arzura', 'Gonzalo Montiel',
#           'Milton Casco', 'Luciano Lollo', 'Lucas Martinez', 'Camilo Mayada',
#           'Jonathan Maidana', 'Arturo Mina', 'Jorge Moreira', 'Luis Olivera',
#           'Augusto Batalla'], dtype=object),
#    'Union Santa Fe': array(['Franco Soldano', 'Lucas Gamba', 'Guido Vadala',
#           'Manuel De Iriondo', 'Nelson Acevedo', 'Mauro Pitton',
#           'Martin Rivero', 'Mauro Cejas', 'Diego Godoy', 'Santiago Magallan',
#           'Diego Villar', 'Emanuel Britez', 'Brian Blasi',
#           'Leonardo Sanchez', 'Agustin Sandona', 'Rodrigo Erramuspe',
#           'Nahuel Zarate', 'Nereo Fernandez'], dtype=object),
#    'Colon Santa Fe': array(['Facundo Pereyra', 'Ismael Blanco', 'Diego Vera', 'Nicolas Silva',
#           'Nicolas Leguizamon', 'Luis Garnier', 'Pablo Ledesma',
#           'Geronimo Poblete', 'Adrian Bastia', 'Cristian Bernardi',
#           'Ivan Torres', 'Fidencio Oviedo', 'German Conti', 'Lucas Ceballos',
#           'Emanuel Olivera', 'Guillermo Ortiz', 'Clemente Rodriguez',
#           'Jorge Broun'], dtype=object),
#    'Boca Juniors': array(['Dario Benedetto', 'Cristian Pavon', 'Carlos Tevez', 'Walter Bou',
#           'Oscar Benitez', 'Rodrigo Bentancur', 'Pablo Perez',
#           'Fernando Gago', 'Lisandro Magallan', 'Frank Fabra',
#           'Gino Peruzzi', 'Juan Insaurralde', 'Fernando Tobio',
#           'Jonathan Silva', 'Santiago Vergini', 'Leonardo Jara',
#           'Guillermo Sara', 'Agustin Rossi'], dtype=object),
#    'Belgrano Cordoba': array(['Matias Suarez', 'Fernando Marquez', 'Mariano Barbieri',
#           'Claudio Bieler', 'Lucas Melano', 'Guillermo Martin Farre',
#           'Jorge Velazquez', 'Federico Lertora', 'Claudio Aquino',
#           'Renzo Saravia', 'Juan Quiroga', 'Sebastian Luna',
#           'Lucas Aveldano', 'Cristian Romero', 'Cristian Lema',
#           'Esteban Espindola', 'Lucas Acosta', 'Juan Olave'], dtype=object),
#    'Temperley': array(['Ariel Colzera', 'Marcos Figueroa', 'Luciano Vazquez',
#           'Leonardo Di Lorenzo', 'Dardo Miloc', 'Emiliano Osuna',
#           'Abel Peralta', 'Matias Sanchez', 'Adrian Arregui', 'Gonzalo Rios',
#           'Alexis Zarate', 'Ignacio Boggino', 'Lucas Mancinelli',
#           'Christian Chimino', 'Gonzalo Escobar', 'Gaston Bojanich',
#           'Gaston Aguirre', 'Leandro de Bortoli', 'Matias Ibanez'],
#          dtype=object),
#    'Aldosivi': array(['Nicolas Miracco', 'Sebastian Penco', 'Neri Bandiera',
#           'Joel Acosta', 'Antonio Medina', 'Roberto Brum',
#           'Sebastian Navarro', 'Nahuel Yeri', 'Pablo Luguercio',
#           'Cristian Llama', 'Leandro Sosa', 'Nicolas Castro', 'Ramiro Arias',
#           'Alan Alegre', 'Franco Canever', 'Ismael Quilez',
#           'Jonathan Galvan', 'Damian Ledesma', 'Gaston Diaz',
#           'Pablo Campodonico', 'Matias Vega'], dtype=object),
#    'Sarmiento Junin': array(['Joaquin Viviani', 'Maximiliano Fornari', 'Adrian Balboa',
#           'Kevin Mercado', 'Gonzalo Di Renzo', 'Rodrigo Depetris',
#           'Hector Cuevas', 'Brian Fernandez', 'Walter Busse',
#           'Lucas Perez Godoy', 'Renzo Spinacci', 'Hamilton Pereira',
#           'Gervasio Nunez', 'Marcos Astina', 'Nicolas Rinaldi',
#           'Patricio Vidal', 'Ariel Kippes', 'Adrian Scifo',
#           'Francisco Dutari', 'Guillermo Ferracutti', 'Alan Aguirre',
#           'Alexis Niz', 'Federico Pieretto', 'Guillermo Cosaro',
#           'Nicolas Bianchi Arce', 'Maximiliano Mendez', 'Julio Chiarini',
#           'Javier Burrai'], dtype=object),
#    'Arsenal Sarandi': array(['Juan Sanchez Sotelo', 'Juan Martin Imbert', 'Joaquin Boghossian',
#           'Julio Rodriguez', 'Renzo Perez', 'Gonzalo Bazan', 'Gonzalo Papa',
#           'Lucas Wilchez', 'Franco Fragapane', 'Juan Brunetta',
#           'Leonardo Rolon', 'Franco Bellocq', 'Maximiliano Calzada',
#           'Jonathan Bottinelli', 'Federico Milo', 'Marcos Curado',
#           'Sergio Velazquez', 'Leandro Marin', 'Claudio Corvalan',
#           'Pablo Santillo', 'Fernando Pellegrino'], dtype=object),
#    'Olimpo Bahia Blanca': array(['Eial Strahman', 'Franco Troyansky', 'Jose Correa',
#           'Fernando Coniglio', 'Emiliano Tellechea', 'Jonatan Blanco',
#           'Rodrigo Cabalucci', 'Martin Perez Guedes', 'Lucas Villarruel',
#           'Francisco Pizzini', 'Jacobo Mansilla', 'Julian Fernandez',
#           'Ezequiel Parnisiari', 'Victor Lopez', 'Yonatan Cabral',
#           'Nicolas Pantaleone', 'Carlos Rodriguez', 'Cristian Villanueva',
#           'Joel Sacks', 'Adrian Gabbarini', 'Nereo Champagne'], dtype=object),
#    'Quilmes': array(['Jonathan Torres', 'Nicolas Benegas', 'Federico Andrada',
#           'Rodrigo Contreras', 'Franco Negri', 'Gabriel Ramirez',
#           'Brandon Obregon', 'Maximiliano Gonzalez', 'Adrian Calello',
#           'Nicolas Da Campo', 'Matias Orihuela', 'Gaston Bottino',
#           'Matias Escobar', 'Tomas Lopez', 'Matias Perez Acuna',
#           'Matias Sarulyte', 'Ismael Benegas', 'Diego Colotto',
#           'Lucas Carrizo', 'Cristian Trombetta', 'Sergio Escudero',
#           'Cesar Rigamonti'], dtype=object),
#    'Godoy Cruz': array(['Santiago Garcia', 'Facundo Silva', 'Juan Garro', 'Javier Correa',
#           'Jaime Ayovi', 'Nicolas Sanchez', 'Guillermo Fernandez',
#           'Gaston Gimenez', 'Angel Gonzalez', 'Fabian Henriquez',
#           'Agustin Verdugo', 'Maximiliano Correa', 'Sebastian Olivarez',
#           'Fabrizio Angileri', 'Leonel Galeano', 'Luciano Abecasis',
#           'Facundo Cobos', 'Diego Viera', 'Marcelo Benitez',
#           'Pablo Alvarado', 'Danilo Ortiz', 'Rodrigo Rey'], dtype=object),
#    'San Martin S.J.': array(['Diego Chaves', 'Ezequiel Montagna', 'Emanuel Dening',
#           'Nicolas Mana', 'Facundo Barcelo', 'Joaquin Molina',
#           'Matias Fissore', 'Marcos Gelabert', 'Nicolas Pelaitay',
#           'Gustavo Villarruel', 'Maximiliano Lugo', 'Emiliano Aguero',
#           'Sergio Sagarzazu', 'Matias Escudero', 'Francisco Mattia',
#           'Patricio Matricardi', 'Mauricio Casierra', 'Javier Capelli',
#           'Pablo Aguilar', 'Luis Ardente', 'Leonardo Corti'], dtype=object),
#    'Atletico DE Rafaela': array(['Mauro Albertengo', 'Marco Bognino', 'Leandro Diaz',
#           'Ramiro Costa', 'Gianfranco Ferrero', 'Enzo Gaggi',
#           'Angelo Martino', 'Emiliano Romero', 'Facundo Soloa',
#           'Gabriel Gudino', 'Lucas Pittinari', 'Fernando Luna',
#           'Walter Serrano', 'Diego Montiel', 'Kevin Itabel', 'Lucas Blondel',
#           'Mathias Abero', 'Teodoro Paredes', 'Gaston Campi',
#           'Oscar Carniello', 'Eros Medaglia', 'Ramiro Macagno',
#           'Lucas Hoyos'], dtype=object),
#    'Gimnasia L.P.': array(['Franco Niell', 'Nicolas Contin', 'Nicolas Mazzola',
#           'Nicolas Ibanez', 'Agustin Ramirez', 'Lucas Lobos',
#           'Daniel Imperiale', 'Ramiro Carrera', 'Luciano Perdomo',
#           'Lorenzo Faravelli', 'Fabian Rinaudo', 'Brahian Aleman',
#           'Sebastian Romero', 'Ezequiel Bonifacio', 'Maximiliano Coronel',
#           'Manuel Guanini', 'Lucas Licht', 'Facundo Oreja',
#           'Sebastian Gorga', 'Mauricio Romero', 'Alexis Arias'], dtype=object),
#    'Patronato': array(['Fernando Telechea', 'Gabriel Vargas', 'Matias Quiroga',
#           'Matias Garrido', 'Damian Arce', 'Alejandro Gagliardi',
#           'Marcelo Guzman', 'Gabriel Graciani', 'Lautaro Comas',
#           'Damian Lemos', 'Nicolas Bertocchi', 'Marcos Maydana',
#           'Lucas Marquez', 'Abel Masuero', 'Walter Andrade',
#           'Lautaro Geminiani', 'Marcos Minetti', 'Renzo Vera', 'Ivan Furios',
#           'Sebastian Bertoli'], dtype=object),
#    'Banfield': array(['Dario Cvitanich', 'Nicolas Bertolo', 'Emanuel Cecchini',
#           'Eric Remedi', 'Mauricio Sperduti', 'Brian Sarmiento',
#           'Alexis Soto', 'Renato Civelli', 'Jorge Rodriguez',
#           'Adrian Sporle', 'Gonzalo Bettini', 'Carlos Matheu',
#           'Hilario Navarro'], dtype=object),
#    'Defensa Y Justicia': array(['Andres Rios', 'Juan Cruz Kaprof', 'Agustin Bouzat',
#           'Nicolas Stefanelli', 'Jonas Gutierrez', 'Leonel Miranda',
#           'Tomas Pochettino', 'Gonzalo Castellani', 'Ignacio Rivero',
#           'Fernando Elizari', 'Hernan Fredes', 'Alexander Barboza',
#           'Rafael Delgado', 'Hugo Silva', 'Mariano Bareiro', 'Tomas Cardona',
#           'Rafael Barrios', 'Gabriel Arias'], dtype=object),
#    'Newells Old Boys': array(['Ignacio Scocco', 'Eugenio Isnaldo', 'Sebastian Prediger',
#           'Juan Sills', 'Facundo Quignon', 'Jalil Elias', 'Mauro Formica',
#           'Braian Rivero', 'Maxi Rodriguez', 'Victor Figueroa',
#           'Hector Fertoli', 'Joel Amoroso', 'Diego Mateo', 'Luis Advincula',
#           'Nestor Moiraghi', 'German Voboril', 'Nehuen Paz',
#           'Milton Valenzuela', 'Franco Escobar', 'Fabricio Formiliano',
#           'Sebastian Dominguez', 'Luciano Pocrnjic'], dtype=object),
#    'Estudiantes L.P.': array(['Javier Toledo', 'Carlos Auzqui', 'Lucas Viatri', 'Augusto Solari',
#           'Juan Cavallaro', 'Israel Damonte', 'Ivan Gomez', 'Rodrigo Brana',
#           'Bautista Cascini', 'Santiago Ascacibar', 'Lucas Rodriguez',
#           'Juan Foyth', 'Jonathan Schunke', 'Facundo Sanchez',
#           'Lucas Diarte', 'Matias Aguirregaray', 'Sebastian Dubarbier',
#           'Leandro Desabato', 'Daniel Sappa', 'Mariano Andujar'],
#          dtype=object),
#    'Talleres Cordoba': array(['Jonathan Menendez', 'Aldo Araujo', 'Sebastian Palacios',
#           'Victorio Ramis', 'Carlos Munoz', 'Emanuel Reynoso',
#           'Juan Ramirez', 'Leonardo Gil', 'Nicolas Gimenez', 'Pablo Guinazu',
#           'Javier Gandolfi', 'Leandro Godoy', 'Juan Komar', 'Ian Escobar',
#           'Carlos Quintana', 'Guillermo Cotugno', 'Guido Herrera'],
#          dtype=object),
#    'Tigre': array(['Lucas Janson', 'Carlos Luna', 'Ramon Mierez',
#           'Emiliano Ellacopulos', 'Alexis Castro', 'Agustin Cardozo',
#           'Lucas Menossi', 'Diego Morales', 'Gaspar Iniguez',
#           'Sebastian Rincon', 'Juan Carlos Blengio', 'Martin Galmarini',
#           'Diego Sosa', 'Bruno Urribarri', 'Oliver Benitez', 'Erik Godoy',
#           'Paulo Lima', 'Mariano Echeverria', 'Javier Garcia',
#           'Nelson Ibanez'], dtype=object),
#    'Huracan': array(['Norberto Briasco Balekian', 'Diego Mendoza', 'Julio Angulo',
#           'Alejandro Romero Gamarra', 'Lucio Compagnucci',
#           'Mariano Gonzalez', 'Javier Iritier', 'Mauro Bogado',
#           'Matias Fritzler', 'Ignacio Pussetto', 'Daniel Montenegro',
#           'Carlos Araujo', 'Federico Mancinelli', 'Lucas Villalba',
#           'Luca Sosa', 'Hugo Nervo', 'Nicolas Romat', 'Mario Risso',
#           'Marcos Diaz'], dtype=object),
#    'Lanus': array(['Lautaro Acosta', 'Marcelino Moreno', 'Jose Sand',
#           'Alejandro Silva', 'Ivan Marcone', 'Miguel Almiron',
#           'Fernando Barrientos', 'Roman Martinez', 'Hernan Toledo',
#           'Nicolas Aguirre', 'Agustin Pelletieri', 'Gabriel Carrasco',
#           'Rolando Garcia', 'Jose Gomez', 'Nicolas Pasquini',
#           'Marcelo Herrera', 'Diego Braghieri', 'Maximiliano Velazquez',
#           'Esteban Andrada', 'Fernando Monetti'], dtype=object),
#    'Independiente': array(['Lucas Albertengo', 'Emanuel Gigliotti', 'German Denis',
#           'Emiliano Rigoni', 'Nery Dominguez', 'Diego Rodriguez',
#           'Martin Benitez', 'Jorge Ortiz', 'Maximiliano Meza',
#           'Ezequiel Barco', 'Walter Erviti', 'Nicolas Tagliafico',
#           'Fabricio Bustos', 'Jorge Figal', 'Alan Franco', 'Sanchez Mino',
#           'Gustavo Toledo', 'Martin Campana'], dtype=object),
#    'Rosario Central': array(['German Herrera', 'Maximiliano Lovera', 'Marco Ruben',
#           'Teofilo Gutierrez', 'Fabian Bordagaray', 'Giovani Lo Celso',
#           'Jose Luis Fernandez', 'Leonel Rivas', 'Washington Camacho',
#           'Jonas Aguirre', 'Walter Montoya', 'Damian Musto',
#           'Federico Carrizo', 'Gustavo Colman', 'Mauricio Martinez',
#           'Javier Pinola', 'Victor Salazar', 'Esteban Burgos',
#           'Jose Leguizamon', 'Paulo Ferrari', 'Cristian Villagra',
#           'Sebastian Sosa', 'Diego Rodriguez'], dtype=object),
#    'Atletico Tucuman': array(['Fernando Zampedri', 'Luis Miguel Rodriguez', 'Cristian Menendez',
#           'Jose Luis Mendez', 'Leandro Gonzalez', 'Rodrigo Aliendro',
#           'David Barbona', 'Nery Leyes', 'Fabio Alvarez', 'Guillermo Acosta',
#           'Bruno Bianchi', 'Ignacio Canuto', 'Leonel Di Placido',
#           'Fernando Evangelista', 'Pablo Rosales', 'Enrique Meza',
#           'Cristian Lucchetti', 'Josue Ayala'], dtype=object),
#    'San Lorenzo': array(['Nicolas Blandi', 'Ezequiel Avila', 'Gonzalo Bergessio',
#           'Bautista Merlini', 'Juan Mercier', 'Ezequiel Cerutti',
#           'Franco Mussis', 'Nestor Ortigoza', 'Fernando Belluschi',
#           'Ruben Botta', 'Sebastian Blanco', 'Paulo Diaz', 'Nicolas Zalazar',
#           'Lautaro Montoya', 'Emmanuel Mas Sgros', 'Matias Caruzzo',
#           'Fabricio Coloccini', 'Gabriel Rojas', 'Marcos Senesi',
#           'Marcos Angeleri', 'Mathias Corujo', 'Sebastian Torrico',
#           'Nicolas Navarro'], dtype=object)},
#   '2017/18': {'Racing Club': array(['Lautaro Martinez', 'Martin Ojeda', 'Lisandro Lopez',
#           'Pablo Maximiliano Cuadra', 'Brian Mansilla', 'Enrique Triverio',
#           'Matias Zaracho', 'Neri Cardozo', 'Ricardo Centurion',
#           'Nery Dominguez', 'Augusto Solari', 'Marcelo Meli',
#           'Diego Gonzalez', 'Egidio Arevalo Rios', 'Renzo Saravia',
#           'Ivan Pillud', 'Rodrigo Schlegel', 'Leonardo Sigali',
#           'Alexis Soto', 'Leandro Grimi', 'Miguel Barbieri', 'Sergio Vittor',
#           'Juan Musso', 'Javier Garcia'], dtype=object),
#    'Velez Sarsfield': array(['Maximiliano Romero', 'Mauro Zarate', 'Agustin Bouzat',
#           'Rodrigo Salinas', 'Federico Andrada', 'Santiago Caseres',
#           'Nicolas Dominguez', 'Guido Mainero', 'Lucas Robertone',
#           'Matias Vargas', 'Leandro Desabato', 'Brian Cufre',
#           'Hernan De La Fuente', 'Lautaro Gianetti', 'Joaquin Laso',
#           'Fabian Cubero', 'Gaston Diaz', 'Francisco Ortega',
#           'Marco Torsiglieri', 'Emiliano Amor', 'Fausto Grillo',
#           'Alan Aguerre', 'Cesar Rigamonti'], dtype=object),
#    'Olimpo Bahia Blanca': array(['David Depetris', 'Franco Troyansky', 'Luis Vila',
#           'Emiliano Tellechea', 'Jonatan Blanco', 'Said Llambay',
#           'Ezequiel Vidal', 'Maximiliano Fornari', 'Lucas Villarruel',
#           'Franco Bellocq', 'Daniel Ibanez', 'Tomas Costa', 'Michael Covea',
#           'Facundo Garcia', 'Lucas Mancinelli', 'Leandro Lacunza',
#           'Pablo Rosales', 'Nicolas Pantaleone', 'Sergio Ojeda',
#           'Matias Cahais', 'Pedro Silva Torrejon', 'Renzo Ramirez',
#           'Cristian Villanueva', 'Cristian Nasuti', 'Nicolas Herranz',
#           'Sebastian Anchoverri', 'Guido Villar', 'Jorge Carranza',
#           'Adrian Gabbarini'], dtype=object),
#    'Union Santa Fe': array(['Franco Soldano', 'Lucas Gamba', 'Nelson Acevedo', 'Mauro Pitton',
#           'Diego Zabala', 'Franco Fragapane', 'Jonathan Bottinelli',
#           'Yeimar Gomez Andrade', 'Damian Martinez', 'Luciano Balbi',
#           'Nereo Fernandez'], dtype=object),
#    'Gimnasia L.P.': array(['Facundo Pereyra', 'Franco Niell', 'Nicolas Contin',
#           'Nicolas Mazzola', 'Nicolas Ibanez', 'Agustin Ramirez',
#           'Nicolas Colazo', 'Agustin Bolivar', 'Lorenzo Faravelli',
#           'Fabian Rinaudo', 'Brahian Aleman', 'Nicolas Dibble',
#           'Omar Alderete', 'Ezequiel Bonifacio', 'Maximiliano Coronel',
#           'Manuel Guanini', 'Lucas Licht', 'Matias Melluso', 'Facundo Oreja',
#           'Alexis Arias'], dtype=object),
#    'Boca Juniors': array(['Dario Benedetto', 'Cristian Pavon', 'Carlos Tevez', 'Walter Bou',
#           'Edwin Cardona', 'Wilmar Barrios', 'Nahitan Nandez',
#           'Emanuel Reynoso', 'Pablo Perez', 'Cristian Espinoza',
#           'Fernando Gago', 'Lisandro Magallan', 'Frank Fabra', 'Paolo Goltz',
#           'Emmanuel Mas Sgros', 'Gino Peruzzi', 'Santiago Vergini',
#           'Leonardo Jara', 'Agustin Rossi'], dtype=object),
#    'Belgrano Cordoba': array(['Matias Suarez', 'Fabricio Brener', 'Mauro Guevgeozian',
#           'Jonathan Ramis', 'Mariano Barbieri', 'Tobias Figueroa',
#           'Epifanio Garcia', 'Jorge Ortiz', 'Jonas Aguirre',
#           'Maximiliano Lugo', 'Juan Brunetta', 'Federico Lertora',
#           'Leonardo Sequeira', 'Joel Amoroso', 'Santiago Martinez',
#           'Tomas Guidara', 'Sebastian Luna', 'Marcelo Benitez',
#           'Cristian Romero', 'Erik Godoy', 'Cristian Lema', 'Lucas Acosta'],
#          dtype=object),
#    'Arsenal Sarandi': array(['Sebastian Lomonaco', 'Diego Chaves', 'Rodrigo Contreras',
#           'Mosquito', 'Emiliano Papa', 'Alejo Antilef', 'Lucas Wilchez',
#           'David Drocco', 'Ramiro Carrera', 'Gabriel Alanis',
#           'Leonardo Rolon', 'Gonzalo Gonzalez', 'German Ferreyra',
#           'Federico Milo', 'Emiliano Purita', 'Facundo Cardozo',
#           'Marcos Curado', 'Sergio Velazquez', 'Facundo Monteseirin',
#           'Claudio Corvalan', 'Mauricio Aquino', 'Pablo Santillo'],
#          dtype=object),
#    'Temperley': array(['Juan Sanchez Sotelo', 'Santiago Giordana', 'Ezequiel Montagna',
#           'Fabian Munoz', 'Ramiro Costa', 'Marcos Figueroa',
#           'Rodrigo De Ciancio', 'Leonardo Di Lorenzo', 'Federico Fattori',
#           'Emiliano Osuna', 'Fernando Brandan', 'Adrian Arregui',
#           'Matias Orihuela', 'Sebastian Martelli', 'Mathias Villasanti',
#           'Adrian Scifo', 'Ignacio Boggino', 'Franco Sosa', 'Marcos Pinto',
#           'Matias Nani', 'William Riveros', 'Gaston Aguirre', 'Josue Ayala'],
#          dtype=object),
#    'Independiente': array(['Juan Manuel Martinez', 'Leandro Fernandez', 'Lucas Albertengo',
#           'Emanuel Gigliotti', 'Diego Rodriguez', 'Jonas Gutierrez',
#           'Nicolas Domingo', 'Fernando Gaibor', 'Gonzalo Veron',
#           'Martin Benitez', 'Maximiliano Meza', 'Ezequiel Barco',
#           'Walter Erviti', 'Emanuel Britez', 'Fabricio Bustos',
#           'Jorge Figal', 'Alan Franco', 'Gaston Silva', 'Sanchez Mino',
#           'Fernando Amorebieta', 'Martin Campana', 'Damian Albil'],
#          dtype=object),
#    'Godoy Cruz': array(['Santiago Garcia', 'Juan Garro', 'Victorio Ramis',
#           'Guillermo Fernandez', 'Gaston Gimenez', 'Juan Andrada',
#           'Jalil Elias', 'Angel Gonzalez', 'Fabian Henriquez',
#           'Leandro Lencinas', 'Felipe Rodriguez', 'Fabrizio Angileri',
#           'Leonel Galeano', 'Luciano Abecasis', 'Tomas Cardona',
#           'Facundo Cobos', 'Diego Viera', 'Christian Javier Baez',
#           'Leonardo Burian'], dtype=object),
#    'Atletico Tucuman': array(['Ismael Blanco', 'Leandro Diaz', 'Javier Toledo',
#           'Luis Miguel Rodriguez', 'Mauricio Affonso', 'Alejandro Melo',
#           'Rodrigo Aliendro', 'David Barbona', 'Nery Leyes',
#           'Gervasio Nunez', 'Fabio Alvarez', 'Guillermo Acosta',
#           'Francisco Guillermo Grahl', 'Gonzalo Freitas', 'Yonatan Cabral',
#           'Andres Lamas', 'Gabriel Risso Patron', 'Franco Sbuttoni',
#           'Nicolas Romat', 'Rafael Garcia', 'Cristian Villagra',
#           'Nahuel Zarate', 'Cristian Lucchetti', 'Augusto Batalla',
#           'Alejandro Sanchez'], dtype=object),
#    'San Martin S.J.': array(['Pablo Daniel Magnin', 'Claudio Spinelli', 'Facundo Barcelo',
#           'Carlos Luque', 'Gabriel Carabajal', 'Marcos Gelabert',
#           'Claudio Mosca', 'Gustavo Villarruel', 'Nicolas Mana',
#           'Maximiliano Rodriguez', 'Alvaro Fernandez', 'Emiliano Aguero',
#           'Matias Escudero', 'Gonzalo Prosperi', 'Arian Pucheta',
#           'Damian Schmidt', 'Leandro Vega', 'Luis Olivera',
#           'Mauricio Casierra', 'Pablo Aguilar', 'Luis Ardente'], dtype=object),
#    'Banfield': array(['Michael Lopez', 'Dario Cvitanich', 'Julian Carranza',
#           'Martin Lucero', 'Nicolas Bertolo', 'Jesus Datolo',
#           'Nicolas Linares', 'Juan Alvarez', 'Enzo Kalinski', 'Pablo Mouche',
#           'Eric Remedi', 'Mauricio Sperduti', 'Renato Civelli',
#           'Alexis Maldonado', 'Jorge Rodriguez', 'Adrian Sporle',
#           'Claudio Bravo', 'Gonzalo Bettini', 'Danilo Ortiz',
#           'Mauricio Arboleda', 'Facundo Altamirano'], dtype=object),
#    'Chacarita Juniors': array(['Elias Alderete', 'Mauro Matos', 'Matias Rodriguez',
#           'Mauro Ezequiel Gonzales', 'Alejandro Gagliardi',
#           'Juan Martin Imbert', 'Nicolas Alvarez', 'Joaquin Ibanez',
#           'Agustin Modula', 'Federico Vismara', 'Javier Mendoza',
#           'Nahuel Menendez', 'Leandro Martinez', 'Miguel Mellado',
#           'Cristian Erbes', 'Frederico Rosso', 'Gian Crocci',
#           'Juan Gonzalez', 'German Re', 'Alan Robledo', 'Gabriel Lazarte',
#           'Hernan Petrik', 'Pedro Fernandez'], dtype=object),
#    'Defensa Y Justicia': array(['Nicolas Fernandez', 'Fernando Marquez', 'Ciro Rius',
#           'Juan Cruz Kaprof', 'Horacio Tijanovich', 'Fabian Bordagaray',
#           'Leonel Miranda', 'Andres Cubas', 'Tomas Pochettino',
#           'Gonzalo Castellani', 'Ignacio Rivero', 'Lisandro Martinez',
#           'Alexander Barboza', 'Rafael Delgado', 'Hugo Silva',
#           'Mariano Bareiro', 'Dylan Gissi', 'Nahuel Molina',
#           'Christian Almeida', 'Pablo Alvarado', 'Luis Jerez',
#           'Gabriel Arias', 'Ezequiel Unsain'], dtype=object),
#    'Huracan': array(['Ramon Abila', 'Norberto Briasco Balekian', 'Andres Chavez',
#           'Diego Mendoza', 'Fernando Coniglio', 'Alejandro Romero Gamarra',
#           'Ricardo Noir', 'Israel Damonte', 'Patricio Toranzo',
#           'Adrian Calello', 'Nicolas Silva', 'Mauro Bogado',
#           'Nazareno Solis', 'Ignacio Pussetto', 'Daniel Montenegro',
#           'Saul Salcedo', 'Carlos Araujo', 'Christian Chimino',
#           'Pablo Alvarez', 'Lucas Villalba', 'Carlos Matheu', 'Hugo Nervo',
#           'Marcos Diaz'], dtype=object),
#    'River Plate': array(['Rafael Santos Borre', 'Ignacio Scocco', 'Rodrigo Mora',
#           'Nicolas De la Cruz', 'Ignacio Fernandez', 'Exequiel Palacios',
#           'Enzo Perez', 'Leonardo Ponzio', 'Ivan Rossi', 'Carlos Auzqui',
#           'Ariel Rojas', 'Gonzalo Martinez', 'Marcelo Saracchi',
#           'Gonzalo Montiel', 'Milton Casco', 'Javier Pinola',
#           'Lucas Martinez', 'Camilo Mayada', 'Jonathan Maidana',
#           'Jorge Moreira', 'German Lux'], dtype=object),
#    'Talleres Cordoba': array(['Jonathan Menendez', 'Aldo Araujo', 'Junior Arias', 'Mauro Ortiz',
#           'Sebastian Palacios', 'Matias Pisano', 'Marcelo Torres',
#           'Santiago Silva', 'Juan Ramirez', 'Fernando Godoy',
#           'Nicolas Gimenez', 'Joao Rojas', 'Pablo Guinazu',
#           'Javier Gandolfi', 'Leandro Godoy', 'Juan Komar',
#           'Nahuel Tenaglia', 'Carlos Quintana', 'Lucas Olaza',
#           'Guido Herrera'], dtype=object),
#    'Tigre': array(['Federico Gonzalez', 'Lucas Janson', 'Carlos Luna',
#           'Denis Stracqualursi', 'Lucas Guiliano Passerini',
#           'Daniel Imperiale', 'Renzo Spinacci', 'Hamilton Pereira',
#           'Ivan Bolano', 'Lucas Menossi', 'Diego Morales',
#           'Sebastian Prediger', 'Javier Iritier', 'Jacobo Mansilla',
#           'Matias Perez Garcia', 'Maximiliano Caire', 'Mathias Abero',
#           'Juan Carlos Blengio', 'Ignacio Canuto', 'Alexis Niz',
#           'Matias Perez Acuna', 'Diego Sosa', 'Carlos Rodriguez',
#           'Julio Chiarini', 'Federico Crivelli'], dtype=object),
#    'Colon Santa Fe': array(['Diego Vera', 'Tomas Chancalay', 'Nicolas Leguizamon',
#           'Javier Correa', 'Mariano Gonzalez', 'Facundo Silva', 'Alan Ruiz',
#           'Pablo Ledesma', 'Adrian Bastia', 'Cristian Bernardi',
#           'Marcelo Estigarribia', 'Matias Fritzler', 'Leonardo Heredia',
#           'Cristian Guanca', 'German Conti', 'Lucas Ceballos',
#           'Gonzalo Escobar', 'Guillermo Ortiz', 'Clemente Rodriguez',
#           'Gustavo Toledo', 'Jonathan Galvan', 'Alexander Dominguez'],
#          dtype=object),
#    'Lanus': array(['Lautaro Acosta', 'Marcelino Moreno', 'Jose Sand', 'Bruno Vides',
#           'German Denis', 'Gonzalo Di Renzo', 'Alejandro Silva',
#           'Ivan Marcone', 'Matias Rojas', 'Matias Sanchez',
#           'Fernando Barrientos', 'Tomas Belmonte', 'Gaston Lodico',
#           'Leandro Maciel', 'Roman Martinez', 'Enzo Ortiz',
#           'Santiago Zurbriggen', 'Dario Caceres', 'Gabriel Carrasco',
#           'Leonel Di Placido', 'Rolando Garcia', 'Nicolas Thaller',
#           'Nicolas Pasquini', 'Marcelo Herrera', 'Diego Braghieri',
#           'Maximiliano Velazquez', 'Esteban Andrada', 'Fernando Monetti'],
#          dtype=object),
#    'Patronato': array(['Sebastian Ribas', 'Adrian Balboa', 'Matias Quiroga',
#           'Matias Garrido', 'Marcelo Guzman', 'Gaston Gil Romero',
#           'Damian Lemos', 'Abel Peralta', 'Martin Rivero',
#           'Alberto Contrera', 'Blas Caceres', 'Lucas Marquez',
#           'Rodrigo Arciero', 'Walter Andrade', 'Lautaro Geminiani',
#           'Agustin Sandona', 'Bruno Urribarri', 'Renzo Vera', 'Luca Sosa',
#           'Sebastian Bertoli'], dtype=object),
#    'Newells Old Boys': array(['Alexis Rodriguez', 'Lisandro Cabrera', 'Luis Leal', 'Juan Sills',
#           'Hernan Bernardello', 'Braian Rivero', 'Joaquin Torres',
#           'Victor Figueroa', 'Hector Fertoli', 'Brian Sarmiento',
#           'Bruno Bianchi', 'Jose San Roman', 'Joaquin Varela',
#           'Leonel Ferroni', 'Fabricio Fontanini', 'Facundo Nadalin',
#           'Fernando Evangelista', 'Nehuen Paz', 'Milton Valenzuela',
#           'Luciano Pocrnjic', 'Nelson Ibanez'], dtype=object),
#    'Estudiantes L.P.': array(['Gaston Fernandez', 'Mariano Pavone', 'Juan Otero', 'Lucas Melano',
#           'Ivan Gomez', 'Rodrigo Brana', 'Carlo Lattanzio',
#           'Pablo Luguercio', 'Fernando Zuqui', 'Bautista Cascini',
#           'Lucas Rodriguez', 'Matias Ruiz Diaz', 'Jonathan Schunke',
#           'Facundo Sanchez', 'Lucas Diarte', 'Gaston Campi',
#           'Sebastian Dubarbier', 'Leandro Desabato', 'Mariano Andujar'],
#          dtype=object),
#    'Rosario Central': array(['German Herrera', 'Maximiliano Lovera', 'Fernando Zampedri',
#           'Marco Ruben', 'Jose Luis Fernandez', 'Maximiliano Gonzalez',
#           'Washington Camacho', 'Leonardo Gil', 'Andres Lioi',
#           'Joaquin Pereyra', 'Joel Lopez Pisano', 'Federico Carrizo',
#           'Gustavo Colman', 'Santiago Romero', 'Mauricio Martinez',
#           'Alfonso Parot', 'Elias Gomez', 'Fernando Tobio',
#           'Jose Leguizamon', 'Paulo Ferrari', 'Jeremias Ledesma',
#           'Diego Rodriguez'], dtype=object),
#    'San Lorenzo': array(['Nicolas Blandi', 'Nicolas Reniero', 'Robert Piris',
#           'Alexis Castro', 'Juan Mercier', 'Ezequiel Cerutti',
#           'Facundo Quignon', 'Gabriel Gudino', 'Nahuel Barrios',
#           'Fernando Belluschi', 'Ruben Botta', 'Franco Moyano',
#           'Leandro Romagnoli', 'Paulo Diaz', 'Matias Caruzzo',
#           'Fabricio Coloccini', 'Gonzalo Rodriguez', 'Gabriel Rojas',
#           'Marcos Senesi', 'Marcos Angeleri', 'Nicolas Navarro'],
#          dtype=object),
#    'Argentinos JRS': array(['Nicolas Gonzalez', 'Ivan Colman', 'Damian Batallini',
#           'Alexis Mac Allister', 'Francis Mac Allister', 'Gaston Machin',
#           'Fausto Montero', 'Leonardo Pisculichi', 'Braian Romero',
#           'Javier Cabrera', 'Kevin Mac Allister', 'Gonzalo Piovi',
#           'Gaston Bojanich', 'Jonathan Sandoval', 'Miguel Torren',
#           'Guillermo Benitez', 'Lucas Chaves'], dtype=object)},
#   '2018/19': {'Union Santa Fe': array(['Franco Soldano', 'Franco Troyansky', 'Nelson Acevedo',
#           'Mauro Pitton', 'Diego Zabala', 'Franco Fragapane',
#           'Jonathan Bottinelli', 'Yeimar Gomez Andrade', 'Damian Martinez',
#           'Claudio Corvalan', 'Nereo Fernandez'], dtype=object),
#    'Gimnasia L.P.': array(['Jan Hurtado', 'Mauro Guevgeozian', 'Santiago Rosales',
#           'Maximiliano Comba', 'Santiago Silva', 'Horacio Tijanovich',
#           'Victor Ayala', 'Lorenzo Faravelli', 'Matias Gomez',
#           'Fabian Rinaudo', 'Ezequiel Bonifacio', 'Maximiliano Coronel',
#           'Manuel Guanini', 'German Guiffrey', 'Lucas Licht',
#           'Matias Melluso', 'Facundo Oreja', 'Gonzalo Piovi', 'Alexis Arias',
#           'Sebastian Moyano'], dtype=object),
#    'Boca Juniors': array(['Dario Benedetto', 'Ramon Abila', 'Cristian Pavon', 'Carlos Tevez',
#           'Mauro Zarate', 'Wilmar Barrios', 'Nahitan Nandez',
#           'Agustin Almendra', 'Emanuel Reynoso', 'Cristian Espinoza',
#           'Fernando Gago', 'Leonardo Balerdi', 'Lisandro Magallan',
#           'Paolo Goltz', 'Carlos Izquierdoz', 'Lisandro Lopez',
#           'Emmanuel Mas Sgros', 'Julio Buffarini', 'Leonardo Jara',
#           'Esteban Andrada', 'Agustin Rossi'], dtype=object),
#    'Belgrano Cordoba': array(['Matias Suarez', 'Mauricio Cuero', 'Diego Mendoza',
#           'Adrian Balboa', 'Denis Rodriguez', 'Gaston Gil Romero',
#           'Jonas Aguirre', 'Maximiliano Lugo', 'Gabriel Alanis',
#           'Juan Brunetta', 'Gabriel Gudino', 'Federico Lertora',
#           'Marcelo Meli', 'Leonardo Sequeira', 'Sebastian Olivarez',
#           'Christian Almeida', 'Tomas Guidara', 'Marcelo Herrera',
#           'Miguel Martinez', 'Matias Nani', 'Juan Quiroga', 'Sebastian Luna',
#           'Hernan Menosse', 'Cesar Rigamonti'], dtype=object),
#    'Godoy Cruz': array(['Santiago Garcia', 'Agustin Aleo', 'Juan Andrada',
#           'Valentin Burgoa', 'Jalil Elias', 'Angel Gonzalez',
#           'Agustin Verdugo', 'Ivan Ramirez', 'Fabrizio Angileri',
#           'Luciano Abecasis', 'Nahuel Arena', 'Tomas Cardona', 'Diego Viera',
#           'Roberto Ramirez'], dtype=object),
#    'Aldosivi': array(['Fernando Telechea', 'Cristian Chavez', 'Matias Pisano',
#           'Denis Stracqualursi', 'Federico Gino', 'Ivan Colman',
#           'Fernando Godoy', 'Javier Iritier', 'Dardo Miloc',
#           'Emiliano Osuna', 'Nahuel Yeri', 'Emiliano Amor', 'Leonel Galeano',
#           'Emanuel Iniguez', 'Jefferson Mena', 'Lucas Villalba',
#           'Juan Daniel Galeano', 'Luciano Pocrnjic'], dtype=object),
#    'Racing Club': array(['Jonathan Cristaldo', 'Lisandro Lopez', 'Matias Zaracho',
#           'Neri Cardozo', 'Ricardo Centurion', 'Marcelo Diaz',
#           'Nery Dominguez', 'Guillermo Fernandez', 'Augusto Solari',
#           'Renzo Saravia', 'Eugenio Mena', 'Alejandro Donatti',
#           'Lucas Orban', 'Ivan Pillud', 'Leonardo Sigali', 'Alexis Soto',
#           'Gabriel Arias', 'Javier Garcia'], dtype=object),
#    'Banfield': array(['Dario Cvitanich', 'Julian Carranza', 'Cristian Agustin Fontana',
#           'Agustin Urzi', 'Nicolas Bertolo', 'Adrian Calello',
#           'Emanuel Cecchini', 'Jesus Datolo', 'Luciano Gomez',
#           'Nicolas Linares', 'Martin Payero', 'Juan Alvarez',
#           'Nicolas Silva', 'Enzo Kalinski', 'Rodrigo Arciero',
#           'Renato Civelli', 'Jorge Rodriguez', 'Adrian Sporle',
#           'Claudio Bravo', 'Danilo Ortiz', 'Mauricio Arboleda',
#           'Facundo Cambeses'], dtype=object),
#    'Defensa Y Justicia': array(['Nicolas Fernandez', 'Ignacio Huguenet', 'Fernando Marquez',
#           'Ciro Rius', 'Domingo Blanco', 'Matias Rojas', 'Ignacio Aliseda',
#           'Alexis Castro', 'Leonel Miranda', 'Gaston Togni',
#           'Lisandro Martinez', 'Alexander Barboza', 'Rafael Delgado',
#           'Julio Gonzalez', 'Nicolas Tripichio', 'Mariano Bareiro',
#           'Ezequiel Unsain'], dtype=object),
#    'River Plate': array(['Rafael Santos Borre', 'Lucas Pratto', 'Ignacio Scocco',
#           'Rodrigo Mora', 'Nicolas De la Cruz', 'Ignacio Fernandez',
#           'Cristian Ferreira', 'Exequiel Palacios', 'Enzo Perez',
#           'Leonardo Ponzio', 'Juan Quintero', 'Bruno Zuculini',
#           'Gonzalo Martinez', 'Gonzalo Montiel', 'Robert Rojas',
#           'Milton Casco', 'Luciano Lollo', 'Javier Pinola', 'Lucas Martinez',
#           'Camilo Mayada', 'Jorge Moreira', 'Franco Armani', 'German Lux'],
#          dtype=object),
#    'Atletico Tucuman': array(['Leandro Diaz', 'Mauro Matos', 'Javier Toledo',
#           'Luis Miguel Rodriguez', 'Rodrigo Aliendro', 'David Barbona',
#           'Nery Leyes', 'Juan Mercier', 'Gervasio Nunez', 'Fabio Alvarez',
#           'Ricardo Noir', 'Guillermo Acosta', 'Mathias Abero',
#           'Bruno Bianchi', 'Yonatan Cabral', 'Andres Lamas',
#           'Gabriel Risso Patron', 'Jose San Roman', 'Cristian Lucchetti'],
#          dtype=object),
#    'Velez Sarsfield': array(['Agustin Bouzat', 'Jonathan Ramis', 'Rodrigo Salinas',
#           'Nicolas Dominguez', 'Gaston Gimenez', 'Guido Mainero',
#           'Lucas Robertone', 'Matias Vargas', 'Thiago Almada',
#           'Leandro Fernandez', 'Luis Abram', 'Brian Cufre',
#           'Hernan De La Fuente', 'Lautaro Gianetti', 'Joaquin Laso',
#           'Fabian Cubero', 'Gaston Diaz', 'Francisco Ortega',
#           'Alexander Dominguez', 'Lucas Hoyos'], dtype=object),
#    'Independiente': array(['Silvio Romero', 'Emanuel Gigliotti', 'Pablo Hernandez',
#           'Nicolas Domingo', 'Fernando Gaibor', 'Pablo Perez',
#           'Francisco Silva', 'Gonzalo Veron', 'Martin Benitez',
#           'Ezequiel Cerutti', 'Francisco Pizzini', 'Braian Romero',
#           'Emanuel Britez', 'Guillermo Burdisso', 'Fabricio Bustos',
#           'Jorge Figal', 'Alan Franco', 'Gaston Silva', 'Sanchez Mino',
#           'Martin Campana'], dtype=object),
#    'Tigre': array(['Federico Gonzalez', 'Lucas Janson', 'Carlos Luna', 'Diego Vera',
#           'Lucas Menossi', 'Walter Montillo', 'Diego Morales', 'Jorge Ortiz',
#           'Sebastian Prediger', 'Juan Cavallaro', 'Matias Perez Garcia',
#           'Maximiliano Caire', 'Gerardo Alcoba', 'Ignacio Canuto',
#           'Nestor Moiraghi', 'Alexis Niz', 'Lucas Rodriguez',
#           'Martin Galmarini', 'Diego Sosa', 'Gonzalo Marinelli',
#           'Augusto Batalla'], dtype=object),
#    'Huracan': array(['Juan Garro', 'Norberto Briasco Balekian', 'Andres Chavez',
#           'Lucas Gamba', 'Israel Damonte', 'Andres Roa', 'Ivan Rossi',
#           'Patricio Toranzo', 'Carlos Auzqui', 'Saul Salcedo',
#           'Omar Alderete', 'Carlos Araujo', 'Christian Chimino',
#           'Federico Mancinelli', 'Walter Perez', 'Pablo Alvarez',
#           'Antony Silva', 'Marcos Diaz'], dtype=object),
#    'Lanus': array(['Pedro de la Vega', 'Lautaro Acosta', 'Marcelino Moreno',
#           'Sebastian Ribas', 'Jorge Pereyra Diaz', 'Tomas Belmonte',
#           'Gaston Lodico', 'Leandro Maciel', 'Facundo Quignon',
#           'Gabriel Carrasco', 'Leonel Di Placido', 'Rolando Garcia',
#           'Jose Gomez', 'Nicolas Thaller', 'Marco Torsiglieri',
#           'Nicolas Pasquini', 'Matias Ibanez', 'Guillermo Sara'],
#          dtype=object),
#    'Talleres Cordoba': array(['Junior Arias', 'Nahuel Bustos', 'Andres Cubas', 'Fernando Juarez',
#           'Gonzalo Maroni', 'Federico Navarro', 'Tomas Pochettino',
#           'Juan Ramirez', 'Joel Sonora', 'Pablo Guinazu', 'Fernando Bersano',
#           'Javier Gandolfi', 'Leandro Godoy', 'Juan Komar', 'Facundo Medina',
#           'Nahuel Tenaglia', 'Enzo Diaz', 'Mauricio Caranta',
#           'Guido Herrera'], dtype=object),
#    'Newells Old Boys': array(['Alexis Rodriguez', 'Francisco Fydriszewski', 'Luis Leal',
#           'Juan Sills', 'Hernan Bernardello', 'Jeronimo Cacciabue',
#           'Mauro Formica', 'Braian Rivero', 'Maxi Rodriguez',
#           'Victor Figueroa', 'Cristian Insaurralde', 'Hector Fertoli',
#           'Joel Amoroso', 'Ivan Piris', 'Mariano Bittolo',
#           'Stefano Callegari', 'Leonel Ferroni', 'Fabricio Fontanini',
#           'Juan Freytes', 'Facundo Nadalin', 'Teodoro Paredes',
#           'Alan Aguerre', 'Nelson Ibanez'], dtype=object),
#    'Estudiantes L.P.': array(['Lucas Albertengo', 'Gaston Fernandez', 'Mariano Pavone',
#           'Francisco Apaolaza', 'Ivan Gomez', 'Rodrigo Brana',
#           'Manuel Castro', 'Nahuel Estevez', 'Matias Pellegrini',
#           'Franco Sivetti', 'Pablo Luguercio', 'Fernando Zuqui',
#           'Lucas Rodriguez', 'Nicolas Bazzana', 'Matias Ruiz Diaz',
#           'Ivan Erquiaga', 'Fernando Evangelista', 'Jonathan Schunke',
#           'Facundo Sanchez', 'Fabian Noguera', 'Mariano Andujar'],
#          dtype=object),
#    'Patronato': array(['Gabriel Avalos', 'German Berterame', 'Ezequiel Rescaldani',
#           'Matias Garrido', 'Federico Bravo', 'Gabriel Carabajal',
#           'Lautaro Comas', 'Gabriel Compagnucci', 'Pablo Ledesma',
#           'Damian Lemos', 'Santiago Brinone', 'Mauricio Sperduti',
#           'Walter Andrade', 'Lucas Ceballos', 'Matias Escudero',
#           'Lautaro Geminiani', 'Dylan Gissi', 'Nicolas Pantaleone',
#           'Agustin Sandona', 'Bruno Urribarri', 'Renzo Vera',
#           'Sebastian Bertoli'], dtype=object),
#    'Rosario Central': array(['German Herrera', 'Maximiliano Lovera', 'Claudio Riano',
#           'Fernando Zampedri', 'Marco Ruben', 'Washington Camacho',
#           'Agustin Allione', 'Leonardo Gil', 'Andres Lioi',
#           'Nestor Ortigoza', 'Federico Carrizo', 'Miguel Barbieri',
#           'Gonzalo Bettini', 'Oscar Cabezas', 'Matias Caruzzo',
#           'Nahuel Molina', 'Alfonso Parot', 'Marcelo Ortiz',
#           'Jeremias Ledesma'], dtype=object),
#    'San Martin S.J.': array(['Martin Bravo', 'Gonzalo Ruben Castillejos', 'Emanuel Dening',
#           'Pablo Palacios', 'Mauro Bogado', 'Fernando Brandan',
#           'Diego Cardozo', 'Franco Cristaldo', 'Matias Fissore',
#           'Marcos Gelabert', 'Francisco Guillermo Grahl', 'Claudio Mosca',
#           'Nazareno Solis', 'Gustavo Villarruel', 'Facundo Erpen',
#           'Ian Escobar', 'Francisco Mattia', 'Federico Milo',
#           'Gonzalo Prosperi', 'Arian Pucheta', 'Juan Rodriguez',
#           'Gianni Rodriguez', 'Jonathan Goitia', 'Alex Silva',
#           'Luis Ardente'], dtype=object),
#    'San Lorenzo': array(['Nicolas Blandi', 'Adolfo Gaich', 'Nicolas Reniero',
#           'Bautista Merlini', 'Franco Mussis', 'Nahuel Barrios',
#           'Fernando Belluschi', 'Ruben Botta', 'Manuel Insaurralde',
#           'Raul Loaiza', 'Roman Martinez', 'Geronimo Poblete', 'Ariel Rojas',
#           'Pablo Mouche', 'Fabricio Coloccini', 'Gianluca Ferrari',
#           'Marcelo Herrera', 'Elias Pereyra', 'Gino Peruzzi',
#           'Gonzalo Rodriguez', 'Gabriel Rojas', 'Victor Salazar',
#           'Marcos Senesi', 'Sebastian Torrico', 'Nicolas Navarro'],
#          dtype=object),
#    'Colon Santa Fe': array(['Gonzalo Bueno', 'Tomas Chancalay', 'Nicolas Leguizamon',
#           'Mariano Gonzalez', 'Alan Ruiz', 'Adrian Bastia',
#           'Cristian Bernardi', 'Guillermo Celis', 'Marcelo Estigarribia',
#           'Matias Fritzler', 'Leonardo Heredia', 'Franco Zuculini',
#           'Gonzalo Escobar', 'Emanuel Olivera', 'Guillermo Ortiz',
#           'Franco Quiroz', 'Clemente Rodriguez', 'Gustavo Toledo',
#           'Alex Vigo', 'Erik Godoy', 'Leonardo Burian'], dtype=object),
#    'San Martin Tucuman': array(['Gonzalo Rodriguez', 'Marcos Figueroa', 'Claudio Bieler',
#           'Fabian Espindola', 'Adrian Arregui', 'Alejandro Altuna',
#           'Tino Costa', 'Matias Garcia', 'Nicolas Gimenez', 'Rodrigo Gomez',
#           'Gonzalo Lamardo', 'Julian Vitale', 'Luciano Pons',
#           'Gustavo Abregu', 'Lucas Acevedo', 'Maximiliano Ramon Martinez',
#           'Rodrigo Moreira', 'Hernan Petrik', 'Emiliano Purita',
#           'Matias Cahais', 'Ignacio Arce', 'Jorge Carranza'], dtype=object),
#    'Argentinos JRS': array(['Raul Bobadilla', 'Francisco Ilarregui', 'Claudio Spinelli',
#           'Gaston Veron', 'Oscar Benitez', 'Ignacio Mendez',
#           'Facundo Barboza', 'Damian Batallini', 'Alexis Mac Allister',
#           'Gaston Machin', 'Fausto Montero', 'Franco Moyano',
#           'Leonardo Pisculichi', 'Hernan Toledo', 'Kevin Mac Allister',
#           'Gaston Bojanich', 'Elias Gomez', 'Carlos Quintana',
#           'Jonathan Sandoval', 'Miguel Torren', 'Enzo Ybanez',
#           'Matias Romero', 'Lucas Chaves'], dtype=object)},
#   '2019/20': {'Velez Sarsfield': array(['Maximiliano Romero', 'Ricardo Centurion', 'Agustin Bouzat',
#           'Leandro Fernandez', 'Lucas Janson', 'Nicolas Dominguez',
#           'Pablo Galdames', 'Gaston Gimenez', 'Lucas Robertone',
#           'Thiago Almada', 'Fernando Gago', 'Luis Abram', 'Brian Cufre',
#           'Hernan De La Fuente', 'Lautaro Gianetti', 'Francisco Ortega',
#           'Tomas Guidara', 'Alexander Dominguez', 'Lucas Hoyos'],
#          dtype=object),
#    'Boca Juniors': array(['Franco Soldano', 'Jan Hurtado', 'Ramon Abila', 'Carlos Tevez',
#           'Mauro Zarate', 'Eduardo Salvio', 'Daniele De Rossi',
#           'Ivan Marcone', 'Sebastian Villa', 'Guillermo Fernandez',
#           'Agustin Almendra', 'Jorman Campuzano', 'Nicolas Capaldo',
#           'Emanuel Reynoso', 'Agustin Obando', 'Alexis Mac Allister',
#           'Junior Alonso', 'Frank Fabra', 'Carlos Izquierdoz',
#           'Lisandro Lopez', 'Emmanuel Mas Sgros', 'Marcelo Weigandt',
#           'Julio Buffarini', 'Esteban Andrada', 'Marcos Diaz'], dtype=object),
#    'River Plate': array(['Matias Suarez', 'Julian Alvarez', 'Rafael Santos Borre',
#           'Lucas Pratto', 'Ignacio Scocco', 'Jorge Carrascal',
#           'Nicolas De la Cruz', 'Ignacio Fernandez', 'Exequiel Palacios',
#           'Enzo Perez', 'Juan Quintero', 'Bruno Zuculini', 'Gonzalo Montiel',
#           'Robert Rojas', 'Paulo Diaz', 'Fabrizio Angileri', 'Milton Casco',
#           'Javier Pinola', 'Lucas Martinez', 'Franco Armani'], dtype=object),
#    'San Lorenzo': array(['Angel Romero', 'Alexander Diaz', 'Nicolas Blandi', 'Adolfo Gaich',
#           'Adam Bareiro', 'Oscar Romero', 'Mauro Pitton', 'Lucas Menossi',
#           'Juan Ramirez', 'Nahuel Barrios', 'Fernando Belluschi',
#           'Matias Palacios', 'Geronimo Poblete', 'Bruno Pitton',
#           'Fabricio Coloccini', 'Gianluca Ferrari', 'Marcelo Herrera',
#           'Gino Peruzzi', 'Gonzalo Rodriguez', 'Victor Salazar',
#           'Ramon Arias', 'Santiago Vergini', 'Sebastian Torrico',
#           'Nicolas Navarro'], dtype=object),
#    'Central Cordoba de Santiago': array(['Nicolas Miracco', 'Gervasio Nunez', 'Jose Valencia',
#           'Jonathan Herrera', 'Joao Rodriguez', 'Cristian Vega',
#           'Facundo Melivillo', 'Juan Daniel Galeano', 'Lisandro Alzugaray',
#           'Franco Cristaldo', 'Marcelo Meli', 'Jonathan Bay',
#           'Cristian Diaz', 'Hugo Vera', 'Ismael Quilez', 'Matias Nani',
#           'Jonathan Galvan', 'Nicolas Correa', 'Oscar Salomon',
#           'Diego Rodriguez'], dtype=object),
#    'Lanus': array(['Nicolas Orsini', 'Carlos Auzqui', 'Pedro de la Vega',
#           'Lautaro Acosta', 'Jose Sand', 'Tomas Belmonte', 'Facundo Quignon',
#           'Marcelino Moreno', 'Lucas Vera', 'Matias Esquivel',
#           'Leonel Di Placido', 'Nicolas Pasquini', 'Lautaro Valenti',
#           'Ezequiel Munoz', 'Alexandro Bernabe', 'Agustin Rossi'],
#          dtype=object),
#    'Arsenal Sarandi': array(['Ezequiel Cerica', 'Juan Manuel Garcia', 'Lautaro Parisi',
#           'Juan Cruz Kaprof', 'Ezequiel Rescaldani', 'Gaston Alvarez Suarez',
#           'Emiliano Mendez', 'Jesus Miguel Soraire', 'Lucas Piovi',
#           'Joel Sonora', 'Nicolas Gimenez', 'Mateo Carabajal',
#           'Emiliano Papa', 'Fabio Pereyra', 'Fernando Torrent',
#           'Franco Sbuttoni', 'Maximiliano Gagliardo', 'Daniel Sappa'],
#          dtype=object),
#    'Godoy Cruz': array(['Sebastian Lomonaco', 'Santiago Garcia', 'Miguel Merentiel',
#           'Juan Brunetta', 'Tomas Badaloni', 'Leandro Vella', 'Juan Andrada',
#           'Valentin Burgoa', 'Kevin Gutierrez', 'Fabian Henriquez',
#           'Agustin Manzur', 'Gabriel Alanis', 'Marcelo Freites',
#           'Gabriel Carrasco', 'Agustin Aleo', 'Nahuel Arena',
#           'Tomas Cardona', 'Joaquin Varela', 'Christian Almeida',
#           'Marcelo Herrera', 'Nestor Adriel Breitenbruch', 'Miguel Jacquet',
#           'Juan Bolado', 'Anders Mehring', 'Roberto Ramirez'], dtype=object),
#    'Patronato': array(['Cristian Tarragona', 'Hugo Silveira', 'Gabriel Avalos',
#           'Lautaro Torres', 'Lucas Mancinelli', 'Julian Chicco',
#           'Dardo Miloc', 'Santiago Rosales', 'Lautaro Comas',
#           'Gabriel Compagnucci', 'Damian Lemos', 'Fernando Luna',
#           'Gabriel Diaz', 'Mathias Abero', 'Christian Chimino',
#           'Federico Mancinelli', 'Matias Escudero', 'Bruno Urribarri',
#           'Oliver Benitez', 'Leandro Marin', 'Matias Ibanez'], dtype=object),
#    'Gimnasia L.P.': array(['Nicolas Contin', 'Horacio Tijanovich', 'Claudio Spinelli',
#           'Pablo Velazquez', 'Erik Ramirez', 'Pablo Maximiliano Cuadra',
#           'Victor Ayala', 'Franco Mussis', 'Jose Paradela',
#           'Maximiliano Comba', 'Matias Garcia', 'Brahian Aleman',
#           'Matias Miranda', 'Leonardo Morales', 'Maximiliano Caire',
#           'Paolo Goltz', 'Marco Torsiglieri', 'Maximiliano Coronel',
#           'Manuel Guanini', 'German Guiffrey', 'Lucas Licht',
#           'Matias Melluso', 'Jorge Broun', 'Alexis Arias'], dtype=object),
#    'Racing Club': array(['Jonathan Cristaldo', 'Dario Cvitanich', 'Lisandro Lopez',
#           'Nicolas Reniero', 'Matias Zaracho', 'Matias Rojas',
#           'Marcelo Diaz', 'David Barbona', 'Hector Fertoli',
#           'Walter Montoya', 'Diego Gonzalez', 'Eugenio Mena',
#           'Alejandro Donatti', 'Lucas Orban', 'Ivan Pillud',
#           'Leonardo Sigali', 'Alexis Soto', 'Nery Dominguez',
#           'Mauricio Martinez', 'Gabriel Arias'], dtype=object),
#    'Defensa Y Justicia': array(['Ignacio Aliseda', 'Nicolas Fernandez', 'Fernando Marquez',
#           'Francisco Pizzini', 'Juan Martin Lucero', 'Neri Cardozo',
#           'Diego Rodriguez', 'Alexis Castro', 'Francisco Cerro',
#           'Bautista Merlini', 'Guido Mainero', 'Ruben Botta', 'Raul Loaiza',
#           'Marcelo Benitez', 'Nicolas Mana', 'Braian Ojeda',
#           'Rafael Delgado', 'Julio Gonzalez', 'Nicolas Tripichio',
#           'Hector Martinez', 'Gonzalo Piovi', 'Juan Rodriguez',
#           'Ezequiel Unsain'], dtype=object),
#    'Atletico Tucuman': array(['Leandro Diaz', 'Javier Toledo', 'Augusto Lotti', 'Lucas Melano',
#           'Jose Luis Fernandez', 'Ramiro Carrera', 'Guillermo Acosta',
#           'Federico Bravo', 'Gonzalo Castellani', 'Ariel Rojas',
#           'Leonardo Heredia', 'Cristian Erbes', 'Bruno Bianchi',
#           'Yonatan Cabral', 'Gabriel Risso Patron', 'Dylan Gissi',
#           'Marcelo Ortiz', 'Fabian Monzon', 'Cristian Lucchetti',
#           'Alejandro Sanchez'], dtype=object),
#    'Newells Old Boys': array(['Rodrigo Salinas', 'Alexis Rodriguez', 'Maxi Rodriguez',
#           'Luis Leal', 'Lucas Albertengo', 'Lucas Villarruel',
#           'Jeronimo Cacciabue', 'Mauro Formica', 'Anibal Moreno',
#           'Braian Rivero', 'Denis Rodriguez', 'Julian Fernandez',
#           'Mariano Bittolo', 'Angelo Gabrielli', 'Facundo Nadalin',
#           'Santiago Gentiletti', 'Cristian Lema', 'Alan Aguerre'],
#          dtype=object),
#    'Aldosivi': array(['Gonzalo Veron', 'Federico Andrada', 'Nazareno Solis',
#           'Sebastian Rincon', 'Leandro Maciel', 'Federico Gino',
#           'Gaston Gil Romero', 'Francisco Guillermo Grahl', 'Roman Martinez',
#           'Facundo Bertoglio', 'Cain Fara', 'Leonel Galeano',
#           'Emanuel Iniguez', 'Lucas Villalba', 'Nicolas Bazzana',
# ...
#           'Pedro Requena', 'Elsar Rodas', 'Christian Ramos',
#           'Emiliano Ciucci', 'Jerson Vasquez', 'Maximo Rabines',
#           'Patrick Zubczuk'], dtype=object),
#    'Deportivo Binacional': array(['Johan Arango', 'Marco Aldair Rodriguez Iraola', 'Hector Zeta',
#           'Sebastian Gularte', 'Roque Ariel Guachire', 'Angel Ojeda',
#           'Andy Polar', 'Yorkman Tello', 'Dahwling Leudo', 'Pablo Labrin',
#           'Angel Romero', 'Jean Deza', 'Mauricio Matzuda', 'Camilo Mancilla',
#           'Diego Angles', 'Eder Fernandez', 'Felipe Mesones', 'Angel Perez',
#           'J Reyes', 'John Fajardo', 'Nery Bareiro', 'Raul Fernandez',
#           'Michael Sotillo'], dtype=object),
#    'Sporting Cristal': array(['Washington Corozo', 'Emanuel Herrera', 'Christopher Olivares',
#           'Christofer Gonzales', 'Kevin Sandoval', 'Horacio Calcaterra',
#           'Jesus Castillo', 'Jorge Cazulo', 'Jose Inga', 'Gerald Tavara',
#           'Jhon Marchan', 'Nilson Loyola', 'Carlos Cabello',
#           'Gianfranco Chavez', 'Johan Madrid', 'Omar Merlo',
#           'Renzo Revoredo', 'Carlos Junior Huerto', 'Carlos Lora',
#           'Emile Franco', 'Renato Solis'], dtype=object),
#    'Alianza Universidad': array(['Enzo Maidana', 'Lionard Pajoy', 'German Pacheco',
#           'Hernan Rengifo', 'Flavio Leonardo Gomez', 'Axel Moyano',
#           'Jack Duran', 'Julio Landauri', 'Giordano Mendoza',
#           'Oscar Vilchez', 'Juan Tuesta', 'Mario Ramirez', 'Juan Morales',
#           'Ederson Mogollon', 'Juan Camara', 'Diego Encinas',
#           'Gianmarco Gambetta', 'Alejandro Ramos', 'Paul Bashi',
#           'Cristian Carbajal', 'Jose Canova', 'Diego Morales'], dtype=object),
#    'FBC Melgar': array(['Irven Avila', 'Hideyoshi Arakaki', 'Johnny Vidales',
#           'Othoniel Arce', 'Alexis Arias', 'Joel Amoroso', 'Omar Tejeda',
#           'Edson Aubert', 'Daniel Cabrera', 'Joel Sanchez', 'Walter Tandazo',
#           'Pablo Miguez', 'Jesus Pretel', 'Hernan Pellerano',
#           'Eduardo Rabanal', 'Alec Deneumostier', 'Paolo Fuentes',
#           'Carlos Neyra', 'Leonardo Mifflin', 'Paolo Reyna', 'Victor Lopez',
#           'Carlos Caceda', 'Angelo Campos'], dtype=object),
#    'Cusco': array(['Ray Sandoval', 'Janio Posito', 'Danilo Carando', 'Josimar Atoche',
#           'Oswaldo Valenzuela', 'Miguel Aucca', 'Alfredo Ramua',
#           'Miguel Carranza', 'William Mimbela', 'Jose Rivera',
#           'Erick Gonzales', 'Eduardo Aranda', 'Franco Bolo', 'Jose Guidino',
#           'Marcos Delgado', 'Jorge Toledo', 'Yordi Vilchez', 'Jair Cespedes',
#           'Edinson Chavez', 'Marco Saravia', 'Miguel Paniagua',
#           'Juan Pretel', 'Carlos Gomez'], dtype=object),
#    'Ayacucho FC': array(['Mauricio Montes', 'Joao Villamarin', 'Carlos Olascagua',
#           'Maximiliano Callorda', 'Gonzalo Papa', 'Leandro Sosa',
#           'Diego Espinoza', 'Robert Ardiles', 'Luis Carranza',
#           'Luis Alvarez', 'Anthony Aoki', 'Jorge Murrugarra',
#           'Jesus Mendieta', 'Diego Minaya', 'Hugo Souza',
#           'Roberto Villamarin', 'Alexis Cossio', 'Minzun Quina',
#           'Fabio Rojas', 'Exar Rosales', 'Angel Zamudio'], dtype=object),
#    'Carlos A. Mannucci': array(['Osnar Noronha', 'Relly Fernandez', 'Jose Carlos Fernandez',
#           'Arley Rodriguez', 'Tarek Carranza', 'Ernest Nungaray',
#           'Ricardo Lagos', 'Jean Pierre Fuentes', 'Carlos Flores',
#           'Javier Nunez', 'Patricio Arce', 'Diego Guastavino',
#           'Sebastian Ramirez', 'Luis Benites', 'Andres Lopez',
#           'Kevin Moreno', 'Giancarlo Pena', 'Horacio Benincasa',
#           'Manuel Corrales', 'Gonzalo Rizzo', 'Jose Gallardo',
#           'Manuel Heredia'], dtype=object),
#    'Atletico Grau': array(['Jeferson Collazos', 'Cristian Lasso', 'Carlos Canales',
#           'Reimond Manco', 'Oshiro Tekeuchi', 'Gary Correa',
#           'Emmanuel Paucar', 'Axel Sanchez', 'Denilson Gonzales',
#           'Neil Marcos', 'Kleiber Palomino', 'Juan Raul Neira',
#           'Jonathan Avila', 'Ronaldo Andia', 'Andy Maelo Castillo',
#           'Jonathan Acasiete', 'Roberto Cespedes', 'Jair Yglesias',
#           'Brackson Leon', 'Piero Anton', 'Bryan Rivas', 'Marcelo Gaona',
#           'Bernardo Medina'], dtype=object),
#    'Carlos Stein': array(['Ivan Bulos', 'Aurelio Gonzales-Vigil', 'Facundo Parra',
#           'Cristian Mejia', 'Carlos Preciado', 'Diego Manicero',
#           'Josimar Vargas', 'Alvaro Medrano', 'Juan Diego Gutierrez',
#           'Aryan Romani', 'Jeferson Navarro', 'Joaquin Aguirre',
#           'Oscar Guerra', 'Camilo Jimenez', 'Jeremy Martin Rostaing',
#           'Cord Jesus Cleque', 'Jesus Rabanal', 'Jorge Luis Taboada',
#           'Janeiler Rivas', 'Roderick Miller', 'Carlos Grados',
#           'Ronald Ruiz'], dtype=object),
#    'U. San Martin': array(['Sebastian Gonzalez Zela', 'Yamir Edhu Oliva Rodriguez',
#           'Franco Zanelatto', 'Santiago Rebagliati', 'Gaspar Gentile',
#           'Nicolas Figueroa', 'Mohamed Karamoko', 'Jhon Vega',
#           'Alfonso Barco', 'Jairo Concha', 'Jordan Guivin', 'Jose Lujan',
#           'Jefferson Portales', 'Yonatan Salas', 'Jose Bolivar',
#           'Werner Schuler', 'Luis Garro', 'Diego Penny'], dtype=object),
#    'Sport Huancayo': array(['Carlos Neumann', 'Charles Monsalvo', 'Ronal Huaccha',
#           'Luis Campos', 'Jorge Bazan', 'Marcos Lliuya', 'Daniel Morales',
#           'Victor Pena', 'Alfredo Rojas', 'Marcio Valverde',
#           'Moises Velasquez', 'Carlos Ross', 'Leonardo Villar',
#           'Herve Kambou', 'Giancarlo Carmona', 'Jimmy Valoyes',
#           'Victor Balta', 'Carlos Caraza', 'Anthony Fuentes', 'Hugo Angeles',
#           'Joseph Vega', 'Federico Nicosia', 'Joel Pinto'], dtype=object),
#    'Academia Cantolao': array(['Jarlin Quintero', 'Mario Ceballos', 'Jesus Castillo',
#           'Yuriel Celi', 'Junior Ponce', 'Sandro Rengifo', 'Mario Tajima',
#           'Augusto Leonel Solis', 'Jhamir D´Arrigo', 'Rodrigo Salinas',
#           'Orlando Contreras', 'Farihd Jasaui', 'Victor Salas',
#           'Cristian Sanchez', 'Brayan Arana', 'Walter Serrano',
#           'Aron Sanchez', 'Jose Ramirez', 'Cesar Barco', 'Orlando Nunez',
#           'Junior Davila', 'Erick Delgado', 'Jose Luis Lozada'], dtype=object),
#    'Deportivo Municipal': array(['Matias Succar', 'Andy Pando', 'Jeremias Bogado', 'Aron Torres',
#           'Rodrigo Vilca', 'Italo Regalado', 'Jean Pierre Archimbaud',
#           'Junior Ross', 'Mario Velarde', 'David Dioses', 'Matias Mansilla',
#           'Jhojan Dominguez', 'Rotceh Aguilar', 'Jose Caballero',
#           'Jorge Torres', 'Eduardo Pita', 'David Diaz', 'Cristian Davila',
#           'Renzo Alfani', 'Yhirbis Cordova', 'Diego Melian'], dtype=object),
#    'Deportivo Llacuabamba': array(['Maximiliano Velasco', 'Daniel Chavez', 'Alex Valera',
#           'Keyvin Paico', 'Christian Adrianzen', 'Niger Vega', 'Cesar Ruiz',
#           'Segundo Acevedo', 'Kelvin Sanchez', 'Kevin Santamaria',
#           'Yerson Pachas', 'Javier Trauco', 'Jose Bustamante',
#           'Arly Benitez', 'Nicolas Raguso', 'Humberto Antonio Mendoza',
#           'Manuel Calderon', 'Fabrizio Roca', 'Felix Uculmana',
#           'Jimmy Vasquez', 'Alvaro Olaya', 'Marlon Ruidias', 'Daniel Prieto',
#           'Mario Ovando', 'Miguel Ramirez'], dtype=object)},
#   '2021/22': {'Cesar Vallejo': array(['Luiz Da Silva', 'Yorleys Mena', 'Santiago Silva',
#           'Arquimedes Figuera', 'Jairo Velez', 'Rodrigo Cuba',
#           'Erick Morillo', 'Ronald Quinteros', 'Frank Ysique',
#           'Donald Millan', 'Franchesco Flores', 'Nahuel Rodriguez',
#           'Leandro Fleitas', 'Renzo Garces', 'Elsar Rodas',
#           'Christian Ramos', 'Emiliano Ciucci', 'Jerson Vasquez',
#           'Juan Quinones', 'Carlos Grados', 'Maximo Rabines',
#           'Jeferson Nolasco'], dtype=object),
#    'Universitario': array(['Alberto Quintero', 'Alexander Succar', 'Enzo Gutierrez',
#           'Alex Valera', 'Guillermo Larios', 'Gerson Barreto',
#           'Rafael Guarderas', 'Jorge Murrugarra', 'Armando Alfageme',
#           'Luis Urruti', 'Hernan Novick', 'Piero Quispe', 'Aldo Corzo',
#           'Nelinho Quina', 'Brayan Velarde', 'Jose Zevallos',
#           'Nelson Cabanillas', 'Federico Alonso', 'Jose Rugel',
#           'Jose Carvallo', 'Patrick Zubczuk'], dtype=object),
#    'Sport Boys': array(['Sebastian Penco', 'Lucas Campana', 'Joao Villamarin',
#           'Jesus Chavez', 'Jorman Aguilar', 'Diego Ramirez', 'Luis Ramirez',
#           'Tarek Carranza', 'Ernest Nungaray', 'Eduardo Uribe',
#           'Jostin Alarcon', 'Camilo Jimenez', 'Jeremy Martin Rostaing',
#           'Paolo Fuentes', 'Claudio Torrejon', 'Renzo Revoredo',
#           'Jose Bolivar', 'Alberto Ampuero', 'Patricio Alvarez'],
#          dtype=object),
#    'FBC Melgar': array(['Cristian Bordacahar', 'Kevin Quevedo', 'Bernardo Cuesta',
#           'Luis Iberico', 'Alexis Arias', 'Jonathan Bustos',
#           'Mariano Vazquez', 'Horacio Orzan', 'Joel Sanchez',
#           'Walter Tandazo', 'Johnny Vidales', 'Freddy Oncoy',
#           'Fabio Pereyra', 'Alejandro Ramos', 'Alec Deneumostier',
#           'Paolo Reyna', 'Jose Lujan', 'Victor Lopez', 'Jefferson Caceres',
#           'Carlos Caceda', 'Ricardo Farro'], dtype=object),
#    'Carlos A. Mannucci': array(['Mauro Guevgeozian', 'Jose Carlos Fernandez', 'Felipe Rodriguez',
#           'Jean Pierre Fuentes', 'Osnar Noronha', 'Relly Fernandez',
#           'Javier Nunez', 'Jesus Barco', 'David Dioses', 'Luis Garcia',
#           'Lucas Rodriguez', 'Kleiber Palomino', 'Gonzalo Godoy',
#           'Kevin Moreno', 'Eduardo Rabanal', 'Horacio Benincasa',
#           'Rafael Lutiger', 'Axel Chavez', 'Renzo Alfani', 'Manuel Heredia'],
#          dtype=object),
#    'UTC': array(['Miguel Curiel', 'Paulo Gallardo', 'Alexis Blanco',
#           'Leonardo Villalba', 'Ray Sandoval', 'Cristian Mejia',
#           'Carlos Diez', 'Alexi Gomez', 'Paulo Goyoneche',
#           'Flavio Leonardo Gomez', 'Freddy Castro', 'Andy Huaman',
#           'Gaspar Gentile', 'Nicolas Ortiz', 'Luis Trujillo', 'Herve Kambou',
#           'Christian Vasquez', 'Josue Estrada', 'Gerardo Gordillo',
#           'Adrian Gutierrez', 'Salomon Libman'], dtype=object),
#    'Alianza Lima': array(['Hernan Barcos', 'Arley Rodriguez', 'Wilmer Aguirre',
#           'Marco Aldair Rodriguez Iraola', 'Sebastian Gonzalez Zela',
#           'Jefferson Farfan', 'Josepmir Ballon', 'Axel Moyano',
#           'Oswaldo Valenzuela', 'Ricardo Lagos', 'Jairo Concha',
#           'Oslimg Mora', 'Yamir Edhu Oliva Rodriguez', 'Edgar Benitez',
#           'Jonathan Lacerda', 'Yordi Vilchez', 'Pablo Miguez', 'Fabio Rojas',
#           'Jefferson Portales', 'Kluiverth Aguilar', 'Carlos Montoya',
#           'Steven Rivadeneyra', 'Angelo Campos'], dtype=object),
#    'Academia Cantolao': array(['William Palacios', 'Gabriel Leyes', 'Jesus Castillo',
#           'Yuriel Celi', 'Mario Tajima', 'Augusto Leonel Solis',
#           'Patricio Arce', 'Ivan Luquetta', 'Diego Otoya', 'Bryan Reyna',
#           'Jhamir D´Arrigo', 'Rodrigo Salinas', 'Carlos Cabello',
#           'Victor Salas', 'Cristian Sanchez', 'Gianmarco Gambetta',
#           'Jorge Toledo', 'Aron Sanchez', 'Jose Ramirez', 'Orlando Nunez',
#           'Christian Gonzalo Limousin', 'Jose Luis Lozada'], dtype=object),
#    'Deportivo Municipal': array(['Roberto Ovelar', 'Hernan Rengifo', 'Alexis Rodriguez',
#           'Erinson Ramirez', 'Hideyoshi Arakaki', 'Alexis Cossio',
#           'Jean Pierre Archimbaud', 'Jhon Vega', 'Piero Ratto',
#           'Jorge Bazan', 'Mario Velarde', 'Jhony Galli', 'Kevin Pena',
#           'Adrian Ascues', 'Luis Cardoza', 'Franco Medina', 'Rotceh Aguilar',
#           'Jose Caballero', 'Carlos Neyra', 'Marco Saravia',
#           'Williams Guzman', 'Freddy Yovera', 'Diego Melian'], dtype=object),
#    'Deportivo Binacional': array(['Johan Arango', 'Marlon de Jesus', 'Andy Polar', 'William Mimbela',
#           'Jose De la Cruz', 'Cristian Alvarez', 'Anthony Rosell',
#           'Angel Perez', 'Angel Ojeda', 'Carlos Flores', 'Angel Romero',
#           'Mario Palomino', 'Juan Pablo Carranza', 'Camilo Mancilla',
#           'Felipe Mesones', 'Adrian Zela', 'Carlos Caraza', 'John Fajardo',
#           'Nicolas Marotta', 'Yhirbis Cordova', 'Raul Fernandez',
#           'Michael Sotillo'], dtype=object),
#    'Cusco': array(['Maximiliano Barreiro', 'Sandro Rengifo', 'Diego Espinoza',
#           'Mauricio Montes', 'Nicolas Royon', 'Edson Aubert',
#           'Yorkman Tello', 'Alfredo Ramua', 'Miguel Carranza',
#           'Victor Cedron', 'Jose Rivera', 'Erick Gonzales', 'Matias Abisab',
#           'Royer Villano', 'Anier Figueroa', 'Jose Velasquez',
#           'Manuel Corrales', 'Jair Cespedes', 'Gonzalo Rizzo', 'Erick Rossi',
#           'Federico Nicosia', 'Eder Hermoza', 'Diego Enriquez'], dtype=object),
#    'Sporting Cristal': array(['Irven Avila', 'Carlos Liza', 'Marcos Riquelme',
#           'Christofer Gonzales', 'Horacio Calcaterra', 'Jesus Castillo',
#           'Jesus Pretel', 'Diego Soto', 'Gerald Tavara', 'Alejandro Hohberg',
#           'Jhon Marchan', 'Joao Grimaldo', 'Nilson Loyola',
#           'Alejandro Gonzalez', 'Gianfranco Chavez', 'Johan Madrid',
#           'Omar Merlo', 'Carlos Lora', 'Alejandro Duarte', 'Renato Solis'],
#          dtype=object),
#    'Alianza Atletico': array(['Ramiro Fergonzi', 'Diego Saffadi', 'Victor Perlaza',
#           'Rinaldo Cruzado', 'Adan Balbin', 'Jeremy Canela', 'Frank Aivar',
#           'Carlos Ascues', 'Kevin Lugo', 'Carlos Correa', 'Piero Serra',
#           'Flavio Fernandez', 'Willy Pretel', 'Jose Guidino',
#           'Manuel Ganoza', 'Jesus Arismendi', 'Alberto Rodriguez',
#           'Juan Barreda', 'Anibal Mello', 'Ignacio Barrios'], dtype=object),
#    'Cienciano': array(['Adrian Ugarriza', 'Danilo Carando', 'Kevin Sandoval',
#           'Luis Alvarez', 'Raziel Garcia', 'Oshiro Tekeuchi',
#           'Jordan Guivin', 'Jorge Molina', 'Abdiel Ayarza', 'Juan Romagnoli',
#           'Lampros Kontogiannis', 'Hansell Riojas', 'Aldair Perleche',
#           'Erick Perleche', 'Koichi Aparicio', 'Juan Diego Lojas',
#           'Ayrthon Quintana', 'Daniel Ferreyra', 'Juniors Barbieri'],
#          dtype=object),
#    'Alianza Universidad': array(['Joyce Conde', 'Carlos Neumann', 'Renato Espinoza', 'Jack Duran',
#           'Julio Landauri', 'Oscar Vilchez', 'Diego Manicero',
#           'Damian Ismodes', 'Reimond Manco', 'Victor Pena', 'Juan Morales',
#           'Axel Sanchez', 'Sebastian Cavero', 'Jonathan Avila',
#           'Juan Camara', 'Paul Bashi', 'Brian Bernaola', 'Cristian Carbajal',
#           'Edinson Chavez', 'Jose Canova', 'Manuel Montero', 'Diego Morales',
#           'Eduardo Figueroa'], dtype=object),
#    'Ayacucho FC': array(['Janio Posito', 'Carlos Olascagua', 'Othoniel Arce',
#           'Guillermo Firpo', 'Leandro Sosa', 'Carlos Beltran',
#           'Jesus Mendieta', 'Robert Ardiles', 'Luis Carranza',
#           'Italo Regalado', 'Anthony Aoki', 'Pablo Lavandeira',
#           'Jose Parodi', 'Emmanuel Paucar', 'Pedro Casique',
#           'Aldair Salazar', 'Joaquin Aguirre', 'Marcos Delgado',
#           'Roberto Villamarin', 'Minzun Quina', 'J Iparraguirre',
#           'Segundo Espinola', 'Maximiliano Cavalotti', 'Italo Espinoza'],
#          dtype=object),
#    'Sport Huancayo': array(['Jarlin Quintero', 'Charles Monsalvo', 'Liliu', 'Oscar Barreto',
#           'Joazhino Arroe', 'Luis Benites', 'Marcos Lliuya',
#           'Daniel Morales', 'Alfredo Rojas', 'Ricardo Salcedo',
#           'Marcio Valverde', 'Leonardo Villar', 'Ronal Huaccha',
#           'Jimmy Perez', 'Francisco Duclos', 'J Reyes', 'Giancarlo Carmona',
#           'Jimmy Valoyes', 'Victor Balta', 'Hugo Angeles', 'Antonio Huaman',
#           'Joel Pinto', 'Angel Zamudio'], dtype=object),
#    'U. San Martin': array(['Carlos Monges', 'Nicolas Figueroa', 'Martin Perez Guedes',
#           'Piero Vivanco', 'Jose Inga', 'Kevin Ruiz', 'Alfonso Barco',
#           'Hector Bazan', 'Franco Zanelatto', 'Gabriel Delgado',
#           'Jose Hurtado Cuero', 'Anthony Gordillo', 'Francesco Cavagna',
#           'Carlos Junior Huerto', 'Yonatan Salas', 'Werner Schuler',
#           'Luis Garro', 'Diego Penny'], dtype=object)}}}

# %%
selected_country='Chile'
season_options = [{'label': i, 'value': i} for i in dropdown_options['{}'.format(selected_country)].keys()]

# %%
season_options
# Out:
# [{'label': '2018/19', 'value': '2018/19'},
#  {'label': '2019/20', 'value': '2019/20'},
#  {'label': '2020/21', 'value': '2020/21'},
#  {'label': '2021/22', 'value': '2021/22'}]

# %%
def create_player_table(df, phase, season):
    """
    Creates table of statistics to display for selected player in a specific phase of the game and season
    :param df: dataframe with player's metrics
    :param phase: phase of the game (attack, build-up, defense, general stats)
    :param season: season of the league
    :return:
        Filtered dataframe with relevant statistics to display
    """
    df_filtered = df[df['league_season'] == season][config_data["DashColumns"][phase]].transpose().reset_index()
    df_filtered.columns = ['Var', 'Value']
    for col in df_filtered['Var'].to_list():
        if col in config_data["PctVars"]:
            df_filtered.loc[df_filtered['Var'] == col, 'Value'] = df_filtered.loc[df_filtered['Var'] == col, 'Value'].apply(lambda x: str(round(x*100))+'%')
        elif col == 'player_preferred_position':
            pass
        else:
            df_filtered.loc[df_filtered['Var'] == col, 'Value'] = df_filtered.loc[df_filtered['Var'] == col, 'Value'].apply(lambda x: round(x*-1, 2) if x < 0 else round(x, 2))

    df_filtered['Feature'] = df_filtered['Var'].map(config_data['ColumnNames'])

    return df_filtered[['Feature', 'Value']]

# %%
player='Lautaro Martinez'
df_player = df_season_players.loc[(df_season_players['player_name'] == player), :]

# %%
df_filtered = df_player[df_player['league_season'] == config_data['Parameters']['current_season']][config_data["DashColumns"]['stats_season']].transpose().reset_index()

# %%
df_filtered
# Out:
#                        index
# 0  player_preferred_position
# 1    player_preferred_number
# 2             player_minutes
# 3         wavg_player_rating
# 4                goals_total
# 5              goals_assists
